# %% [markdown]
# # MongoDB Atlas

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://{user_name}:{urllib.parse.quote_plus(pwd)}@cluster0.xh25e.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"
")
db = client.test
client

# %%
import pymongo
import urllib 

USR = "YourUserName" # User created by us

# Auto Generated Password or Password set by You
# Update according to your set password for autogenerated password
PWD = "PWD" 

DB_NAME = "SomeDB" # Specifiy a Database Name

# Connection URL
CONNECTION_URL = f"mongodb+srv://YourUserName:PWD@cluster0.6op2t.mongodb.net/Test?retryWrites=true&w=majority"
# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]

# Create a Collection Name
COLLECTION_NAME = "Products"
collection = dataBase[COLLECTION_NAME]

# Create a List of Records
list_of_records = [
    {'companyName': 'Something',
     'product': 'Some Products1',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'Something',
     'product': 'Some Products2',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'Something',
     'product': 'Some Products3',
     'courseOffered': 'Data Science Masters Program'}
]

# insert above records in the collection
rec = collection.insert_many(list_of_records)

# Lets Verify all the record at once present in the record with all the fields
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")

# %%
DEFAULT_CONNECTION_URL = "mongodb+srv://YourUserName:PWD@cluster0.xh25e.mongodb.net/Test?retryWrites=true&w=majority"
DB_NAME = "SomeDB"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)
client

# %%
import urllib 

user="YourUserName"
pwd = "PWD"
DB_NAME = "SomeDB"

DEFAULT_CONNECTION_URL = f"mongodb+srv://{user}:{urllib.parse.quote_plus(pwd)}@cluster0.xh25e.mongodb.net/{DB_NAME}?retryWrites=true&w=majority"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# Create a DB
dataBase = client[DB_NAME]
dataBase

# %%
client.list_database_names()

# %%
collection_name = "products"
collection = dataBase[collection_name]
collection

# %%
record = [
    {'key1':'value1',
     'key2':'value2',
     'key3':'value3',
     'key5':'value2'},
    {'companyName': 'Something',
     'product': 'Some products1',
     'courseOffered': 'Machine Learning with Deployment'},

    {'companyName': 'Something',
     'product': 'Some products2',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},

    {'companyName': 'Something',
     'product': 'Some products3',
     'courseOffered': 'Data Science Masters Program'},
]

rec = collection.insert_many(record)

# %%
# lets print he unique ID that of the record that we have inserted -
ID = rec.inserted_ids
for index, unique_id in enumerate(ID):
    print(f"{index}. {unique_id}")

# %%
COLLECTION_NAME = "Faculties5"
faculties = dataBase[COLLECTION_NAME]

list_of_records_user_defined_id = [
    {"_id": "1",
    "companyName": "Something",
    "Faculty": "S. Kumar"},
    {"_id": "2",
    "companyName": "Something",
    "Faculty": "V. Sagar"},
    {"_id": "3",
    "companyName": "Something",
    "Faculty": "V. Sagar"},
]

faculties_record = faculties.insert_many(list_of_records_user_defined_id)
faculties_record

# %%
all_rec = faculties.find()
for index, record in enumerate(all_rec):
    print(f"{index}: {record}")

# %%
query2 = {"_id":{"$lt":'3'}}

desired_rec = faculties.find(query2)
for i in desired_rec:
    print(i)

# %%
# Lets add some random data in faculties
random_data = [
    {'_id': '555', 'companyName': 'Something', 'Faculty': 'XYZ'},
    {'_id': '4565', 'companyName': 'Something', 'Faculty': 'ABC'},
    {'_id': '585', 'companyName': 'Something', 'Faculty': 'PQR'},
]

faculties.insert_many(random_data)

# %%
query_to_delete = {"_id":{"$gt":'3'}}
faculties.delete_many(query_to_delete)

# %% [markdown]
# ## Important things

# %% [markdown]
# #### 1 The correct connection string

# %% [markdown]
# #### 2 The correct user name and password

# %% [markdown]
# #### 3 The correct database name

# %% [markdown]
# #### 4 Having proper access of read and write

# %% [markdown]
# #### 5 Whitelist the IP adress (0.0.0.0/0)
