# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index=pd.date_range('2019-01-01', periods=1000), columns=['value'])
df.head()
# Out:
#                value
# 2019-01-01  0.682735
# 2019-01-02 -0.568073
# 2019-01-03 -0.459120
# 2019-01-04  2.559346
# 2019-01-05  0.141802

# %%
df.value=df.cumsum()
df.head()
# Out:
#                value
# 2019-01-01  0.791012
# 2019-01-02  2.918081
# 2019-01-03  3.231332
# 2019-01-04  3.624830
# 2019-01-05  3.381374

# %%
df.plot(figsize=(5,5))

# %%
s = pd.Series(randn(1000), index=pd.date_range('2019-01-01', periods=1000))
s.head()
# Out:
# 2019-01-01   -0.795771
# 2019-01-02   -1.317731
# 2019-01-03   -1.106135
# 2019-01-04    0.204472
# 2019-01-05   -0.391270
# Freq: D, dtype: float64

# %%
s = s.cumsum()
s.head()
# Out:
# 2019-01-01    1.495831
# 2019-01-02    2.916669
# 2019-01-03    2.224758
# 2019-01-04    2.118086
# 2019-01-05    1.933458
# Freq: D, dtype: float64

# %%
s.plot()

# %%
iris = sns.load_dataset('iris')
print(iris.shape)
iris.head()
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(8,5), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
s.plot(kind='bar')

# %%
iris['sepal_length'].plot()

# %%
iris['sepal_length'].plot(kind='bar')

# %%
iris.iloc[0,0:-1].plot(kind='bar')

# %%
a=iris.iloc[0,0:-1]
a
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
a.plot(kind='bar')

# %%
a.plot()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f4dd07109e31> in <module>
# ----> 1 iris['sepal_length'].plot(kind='scatter')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
# --> 794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#     795         elif kind in self._series_kinds:
#     796             if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
iris.plot(kind='scatter', x='sepal_length',y='sepal_width')

# %%
b = iris.drop(['species'], axis = 1)

# %%
b.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
b.iloc[0].plot(kind='bar')

# %%
b.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')
print(titanic.shape)
titanic.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.plot(kind='line')

# %%
titanic.catplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-df35c85bfb49> in <module>
# ----> 1 titanic.catplot()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'catplot'

# %%
titanic.plot.bar()

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic['pclass'].plot()

# %%
titanic['pclass'].plot.bar()

# %%
df = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0 -1.375737  0.284251 -0.165354 -1.926003
# 1  0.991880  0.096684  0.866985  0.533052
# 2 -0.483448 -1.245166 -0.870781  0.402780
# 3 -0.647096  1.135206 -1.783693  0.451237
# 4 -0.959786  1.417914 -1.137573 -0.513906

# %%
plt.plot(df)

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
iris.plot(kind='hist')

# %%
iris.plot(kind='hist', stacked=True)

# %%
iris.plot.hist(bins=70,figsize=(8,5))

# %%
iris.plot.hist(bins=100,figsize=(8,5))

# %%
iris.plot.hist(bins=100,figsize=(8,5), orientation='horizontal')

# %%
iris.plot.histh(bins=100,figsize=(8,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-6c72134bed00> in <module>
# ----> 1 iris.plot.histh(bins=100,figsize=(8,5))
#
# AttributeError: 'PlotAccessor' object has no attribute 'histh'

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
type(iris['sepal_width'].diff())
# Out:
# pandas.core.series.Series

# %%
iris['sepal_width'].diff().plot()

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True, bins=50)

# %%
iris.iloc[:,0:-1].diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C2DF26A58>,
# ...
#       dtype=object)

# %%
iris.iloc[:,0:-1].diff().plot(kind='hist')

# %%
iris.iloc[:,0:-1].diff().hist(figsize=(5,5), color='r', alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C2F5CE358>,
# ...
#       dtype=object)

# %%
iris.plot(kind='scatter', x='sepal_width', y='petal_width')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x='sepal_width', y='petal_width', c='petal_length')

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
ax = iris.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
iris.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'width')

# %%
iris.plot.scatter(x = 'sepal_width', y = 'petal_width', ax=ax, label = 'width')

# %%
iris.plot.scatter(x = 'sepal_width', y = 'petal_width', c='sepal_length', s=100)

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'petal_width')

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', c='sepal_length')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4987f97add6d> in <module>
# ----> 1 iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', c='sepal_length')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1586             kwargs["gridsize"] = gridsize
#    1587
# -> 1588         return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#    1589
#    1590
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ...

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', C='sepal_length')

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', C='sepal_length', s=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1d2fc0a40bf1> in <module>
# ----> 1 iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', C='sepal_length', s=100)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1586             kwargs["gridsize"] = gridsize
#    1587
# -> 1588         return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#    1589
#    1590
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ...

# %%
iris.plot.hexbin(x = 'sepal_width', y = 'petal_width', C='sepal_length', gridsize=20)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.iloc[0,0:-1]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
iris.iloc[0,0:-1].plot.pie()

# %%
iris.iloc[0,0:-1].plot.pie(figsize=(5,10))

# %%
iris.iloc[0,0:-1].plot.pie(figsize=(5,5), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F89586C18>],
#       dtype=object)

# %%
iris.iloc[0:4,0:-1].T.plot.pie(figsize=(20,20), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F89A990B8>,
# ...
#       dtype=object)

# %%
iris.iloc[0:4,0:-1].T.plot.pie(figsize=(20,20), subplots=True, fontsize=16)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F89D18CC0>,
# ...
#       dtype=object)

# %%
iris.iloc[0:4,0:-1].T.plot.pie(figsize=(20,20), subplots=True, fontsize=16, autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F8A1DE8D0>,
# ...
#       dtype=object)

# %%
d = pd.Series(randn(5)+2, index=['a','b','c','d','e'])
d
# Out:
# a    2.113138
# b    1.213076
# c    1.203588
# d    2.089689
# e    2.243483
# dtype: float64

# %%
d.plot.pie()

# %%
iris.plot.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-63370fe9e064> in <module>
# ----> 1 iris.plot.scatter_matrix()
#
# AttributeError: 'PlotAccessor' object has no attribute 'scatter_matrix'

# %%
from pandas.plotting import scatter_matrix as sm

# %%
sm(iris, figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F8D213908>,
# ...
#       dtype=object)

# %%
sm(iris, figsize=(15,10), diagonal='kde', color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F8D07E240>,
# ...
#       dtype=object)

# %%
sm(iris, figsize=(15,10), diagonal='kde', color='r', s=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F8D85AC88>,
# ...
#       dtype=object)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.kde()

# %%
iris.plot.scatter(x='sepal_length', y='sepal_length')

# %%
a = iris
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
s.plot.kde()

# %%
s.cumsum().plot(style='r--',label = 'Series', legend = True)

# %%
iris.plot(legend = True, figsize = (10, 5), logy = True)

# %%
a = pd.concat([iris.sepal_length,iris.petal_length], axis=1)
a
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
ax = a.plot()

# %%
b = pd.concat([iris.sepal_width,iris.petal_width], axis=1)
y = b.plot()

# %%
b.plot(figsize = (16,10), secondary_y=True, ax=ax)

# %%
a.plot()

# %%
a.plot(x_compat = True)

# %%
iris.plot()

# %%
iris.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F8F999E80>,
# ...
#       dtype=object)

# %%
iris.plot(subplots=True, figsize=(16,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F924A3400>,
# ...
#       dtype=object)

# %%
iris.plot(subplots=True, figsize=(16,8), layout = (2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F92A32A58>,
# ...
#       dtype=object)

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
map_df
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open London_Borough_Excluding_MHW.shx or London_Borough_Excluding_MHW.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-12-ec3b670fa972> in <module>
# ----> 1 map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
#       2 map_df
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
# ...

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
